# %%
from pandas import DataFrame
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

#graph for normal driving behavior with acceleration x
# %matplotlib inline
df_normal = pd.read_csv("/Users/dhanushka/Desktop/mydata/fypit/anaconda/data/slow2.csv")

fig_normal = plt.figure(figsize=(10, 10,))
plt.scatter(df_normal['time'].abs(), (df_normal['X']+0.5))

# %%
#Frequency graph for normal data  acceleration x
pd.cut((df_normal['X']+0.5).abs(), bins=[0,0.5,1,1.5,2,2.5,3,3.5,4,4.5,5,5.5,6]).value_counts().sort_index()
# Out:
# (0.0, 0.5]    5649
# (0.5, 1.0]    2917
# (1.0, 1.5]     968
# (1.5, 2.0]     243
# (2.0, 2.5]      74
# (2.5, 3.0]      37
# (3.0, 3.5]      15
# (3.5, 4.0]       7
# (4.0, 4.5]       3
# (4.5, 5.0]       0
# (5.0, 5.5]       0
# (5.5, 6.0]       0
# Name: X, dtype: int64

# %%
# Frequency graph for normal data  acceleration x

plot_data_normal= pd.cut((df_normal['X']+0.5).abs(), bins=[0,0.5,1,1.5,2,2.5,3,3.5,4,4.5,5,5.5,6]).value_counts()
plt.plot([0.25, 0.75, 1.25, 1.75,2.25, 2.75, 3.25, 3.75, 4.25, 4.75, 5.25, 5.75], plot_data_normal)

# %%
(df_normal['X']+0.5).abs().std()
# Out:
# 0.4638831855925243

# %%
(df_normal['X']+0.5).abs().mean()
# Out:
# 0.5414686667002909

# %%
#graph for abnormal driving behavior with acceleration x

# %matplotlib inline
df_abnormal = pd.read_csv("/Users/dhanushka/Desktop/mydata/fypit/anaconda/data/abnormal2.csv")

fig_abnormal = plt.figure(figsize=(10, 10,))
plt.scatter(df_abnormal['time'].abs(), (df_abnormal['X']-1))

# %%
pd.cut((df_abnormal['X']-1).abs(), bins=[0,0.5,1,1.5,2,2.5,3,3.5,4,4.5,5,5.5,6]).value_counts().sort_index()
# Out:
# (0.0, 0.5]    3681
# (0.5, 1.0]    2845
# (1.0, 1.5]    1688
# (1.5, 2.0]     867
# (2.0, 2.5]     396
# (2.5, 3.0]     188
# (3.0, 3.5]      91
# (3.5, 4.0]      41
# (4.0, 4.5]      25
# (4.5, 5.0]      19
# (5.0, 5.5]      11
# (5.5, 6.0]       5
# Name: X, dtype: int64

# %%
# Frequency graph for abnormal data  acceleration x

plot_data_abnormal= pd.cut((df_abnormal['X']-1).abs(), bins=[0,0.5,1,1.5,2,2.5,3,3.5,4,4.5,5,5.5,6]).value_counts().sort_index()
plt.plot([0.25, 0.75, 1.25, 1.75,2.25, 2.75, 3.25, 3.75, 4.25, 4.75, 5.25, 5.75], plot_data_abnormal)

# %%
(df_abnormal['X']-1).abs().std()
# Out:
# 0.7817735877645482

# %%
(df_abnormal['X']-1).abs().mean()
# Out:
# 0.8835462693554896

# %%
df_normal_y = pd.read_csv("/Users/dhanushka/Desktop/mydata/fypit/anaconda/data/slow3.csv")
fig_normal_y = plt.figure(figsize=(10, 10,))
plt.scatter(df_normal_y['time'].abs(), (df_normal_y['Y']+3))

# %%
pd.cut((df_normal_y['Y']+3).abs(), bins=[0,0.5,1,1.5,2,2.5,3,3.5,4,4.5,5,5.5,6]).value_counts().sort_index()
# Out:
# (0.0, 0.5]    4115
# (0.5, 1.0]    3028
# (1.0, 1.5]    1661
# (1.5, 2.0]     588
# (2.0, 2.5]     218
# (2.5, 3.0]      63
# (3.0, 3.5]      21
# (3.5, 4.0]       7
# (4.0, 4.5]       6
# (4.5, 5.0]       1
# (5.0, 5.5]       0
# (5.5, 6.0]       0
# Name: Y, dtype: int64

# %%
plot_data_normal_y= pd.cut((df_normal_y['Y']+3).abs(), bins=[0,0.5,1,1.5,2,2.5,3,3.5,4,4.5,5,5.5,6]).value_counts().sort_index()
plt.plot([0.25, 0.75, 1.25, 1.75,2.25, 2.75, 3.25, 3.75, 4.25, 4.75, 5.25, 5.75], plot_data_normal_y)

# %%
(df_normal_y['Y']+3).abs().std()
# Out:
# 0.5649675595400109

# %%
(df_normal_y['Y']+3).abs().mean()
# Out:
# 0.7223566391635774

# %%
df_abnormal_y = pd.read_csv("/Users/dhanushka/Desktop/mydata/fypit/anaconda/data/abnormal4.csv")
fig_abnormal_y = plt.figure(figsize=(10, 10,))
plt.scatter(df_abnormal_y['time'].abs(), (df_abnormal_y['Y']+2.5))

# %%
pd.cut((df_abnormal_y['Y']+2.5).abs(), bins=[0,0.5,1,1.5,2,2.5,3,3.5,4,4.5,5,5.5,6]).value_counts().sort_index()
# Out:
# (0.0, 0.5]    2695
# (0.5, 1.0]    2038
# (1.0, 1.5]    1309
# (1.5, 2.0]     703
# (2.0, 2.5]     369
# (2.5, 3.0]     175
# (3.0, 3.5]      79
# (3.5, 4.0]      56
# (4.0, 4.5]      20
# (4.5, 5.0]       6
# (5.0, 5.5]      11
# (5.5, 6.0]       3
# Name: Y, dtype: int64

# %%
plot_data_abnormal_y= pd.cut((df_abnormal_y['Y']+2.5).abs(), bins=[0,0.5,1,1.5,2,2.5,3,3.5,4,4.5,5,5.5,6]).value_counts().sort_index()
plt.plot([0.25, 0.75, 1.25, 1.75,2.25, 2.75, 3.25, 3.75, 4.25, 4.75, 5.25, 5.75], plot_data_abnormal_y)

# %%
(df_abnormal_y['Y']+2.5).abs().std()
# Out:
# 0.8185482254309399

# %%
(df_abnormal_y['Y']+2.5).abs().mean()
# Out:
# 0.9340617989028653
